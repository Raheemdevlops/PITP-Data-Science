# %% [markdown]
# <a href="https://colab.research.google.com/github/Raheemdevlops/PITP-Data-Science/blob/main/PITP%20Python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(5):
  if i==1:
    print("PITP Phase II")
  else:
      print("PITP")

# %%
weekly_tasks = {
    'Monday':    "Team meeting",
    "Tuesday":   "Code review",
    "Wednesday": "Client call",
    "Thursday":  "Testing",
    "Friday":    "Deployment"
}
print(weekly_tasks['Thursday'])
# Out:
# Testing

# %%
def calculate(a, b):
    return a+b, a-b, a*b, a/b
add, sub, mult, div = calculate(14, 2)
print(add, sub, mult, div)
# Out:
# 16 12 28 7.0
